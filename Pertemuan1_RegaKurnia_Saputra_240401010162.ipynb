# %% [markdown]
# <a href="https://colab.research.google.com/github/RegaKurnia/Data_Science-2026/blob/main/Pertemuan1_RegaKurnia_Saputra_240401010162.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Rega Kurnia Saputra
# Nim : 240401010162
# Kelas : IF401

# %%
print ("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
nama = "Rega Kurnia Saputra"
angkatan = 2024

print(f"halo, nama saya {nama} angakatan {angkatan}")
# Out:
# halo, nama saya Rega Kurnia Saputra angakatan 2024

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
for i, tool in enumerate(tools, 1):
  print (f"{i}.{tool}")
# Out:
# 1.Python
# 2.Google Colab
# 3.Jupyter Notebook
# 4.GitHub

# %%
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Rega Kurnia Saputra", "Informatika", "2024"))
# Out:
# Rega Kurnia Saputra | Informatika | 2024

# %% [markdown]
# Apa yang Dipelajari : Dasar Python: print(), variabel, list, loop for, enumerate(), dan function.

# %% [markdown]
# Temuan Utama : Python dapat digunakan untuk membuat program sederhana, mengelola data dalam list, dan membuat fungsi yang dapat digunakan kembali.

# %% [markdown]
# Keterbatasan : Belum ada pengolahan data, visualisasi, maupun analisis statistik.
